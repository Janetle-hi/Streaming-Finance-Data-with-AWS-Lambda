# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('results.csv')
df.head(10)
# Out:
#   company_name  highest_price                   datetime  hour
# 0         BYND     104.709999  2021-05-11 09:55:00-04:00     9
# 1         BYND     106.460999  2021-05-11 10:55:00-04:00    10
# 2         BYND     107.695000  2021-05-11 11:55:00-04:00    11
# 3         BYND     108.839996  2021-05-11 12:55:00-04:00    12
# 4         BYND     110.660004  2021-05-11 13:45:00-04:00    13
# 5         BYND     110.699997  2021-05-11 14:50:00-04:00    14
# 6         BYND     110.699997  2021-05-11 14:45:00-04:00    14
# 7         BYND     110.699997  2021-05-11 14:55:00-04:00    14
# 8         BYND     110.680000  2021-05-11 15:30:00-04:00    15
# 9         DDOG      77.040001  2021-05-11 09:55:00-04:00     9

# %% [markdown]
# #### Firstly, let's see the trend in the stock price of 10 companies on May 11

# %%
plt.figure(figsize=(15,5))
ax = sns.lineplot(x='hour',y='highest_price',data=df,hue='company_name')

# %% [markdown]
# #### We can see the stock prices were quite stable without any significant spike. Let's take a closer look at each company

# %%
for company in df['company_name'].unique():
    print('Company:',company)
    df_trend = df[df['company_name'] == company].loc[:,['hour','highest_price']]
    print(df_trend.set_index('hour').plot(kind='line'))
    plt.show()
# Out:
# Company: BYND
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: DDOG
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: FB
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: NFLX
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: OKTA
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: PINS
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: SHOP
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: SNAP
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: SQ
# AxesSubplot(0.125,0.125;0.775x0.755)
# Company: TTD
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Stock price of all 10 companies increased on May 11, 2021 <br />
# ●	Beyond Meat (BYND) <br />
# ●	Datadog (DDOG) <br />
# ●	Facebook (FB) <br />
# ●	Netflix (NFLX) <br />
# ●	Okta (OKTA) <br />
# ●	Pinterest (PINS)<br />
# ●	Shopify (SHOP)  <br />
# ●	Snap (SNAP) <br />
# ●	Square (SQ) <br />
# ●	The Trade Desk (TTD)

# %% [markdown]
# ### Opening vs Closing Price

# %%
sns.set(style="whitegrid")

df9 = df[(df['hour'] == 9)]

fig = plt.figure(figsize=(15,5))

bar_company = sns.barplot(x="company_name", y="highest_price", data=df9)

bar_company.set(xlabel='Company', ylabel='Highest Price at first trading hour')

plt.show()

# %%
sns.set(style="whitegrid")

df15 = df[(df['hour'] == 15)]

fig = plt.figure(figsize=(15,5))

bar_company = sns.barplot(x="company_name", y="highest_price", data=df15)

bar_company.set(xlabel='Company', ylabel='Highest Price at last trading hour')

plt.show()
